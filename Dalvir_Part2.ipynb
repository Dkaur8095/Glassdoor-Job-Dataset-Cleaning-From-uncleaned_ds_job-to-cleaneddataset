# %% [markdown]
# ## Part 2: Data Cleaning
# Download the Uncleaned_DS_Jobs.csv file. Use appropriate data cleaning techniques and methods in Pandas to convert the raw file into the clean data structure as show in the reference file “Cleaned_DS_Jobs.csv” file. Review each column and look at the data and if it makes sense.
#
# Hints:
# •Missing values are known as -1 in this dataset
#
# •Delete columns that are not in the Cleaned version.
#
# •In the salary_estimate column, delete the text (Glassdoor est.)
#
# •In the company_name column, delete everything after the “\n”
#
# •Review the location column and look for inconsistencies: You might need to split the column into 3 parts (State, location, City)
#
# •In the industry column, replace -1 with n/a . Note this is only for the industry column. For other columns -1 will mean something else and hence can be dropped or filled in with other values
#
# •Split the salary column into 3 parts, minimum, average, maximum salary
#
# •From the job description column, extract the most popular skillfound in the corresponding job description and 0 if the skill is not found in the corresponding job description.
#
#
# The provided hints address some of the specific cleaning tasks, but additional cleaning steps may be required. The end result should match the structure and cleanliness of the reference file.
# Export/save file to a .csv using pandas.s (Python, excel, tableau, power_bi, sql,aws) and create separate columns for each with values 1/0 . 1 if the skill is

# %%
import pandas as pd

# %%
uncleaned_data = pd.read_csv(r'C:\Users\PC\Desktop\Python Assignment\Uncleaned_DS_jobs.csv')

# %% [markdown]
# ## Delete columns that are not in the Cleaned version.

# %%
columns_to_drop = ['index', 'Competitors',] 
uncleaned_data = uncleaned_data.drop(columns=columns_to_drop, errors='ignore')

# %% [markdown]
# ## In the salary_estimate column, delete the text (Glassdoor est.)

# %%
uncleaned_data['Salary_Estimate'] = uncleaned_data['Salary_Estimate'].str.replace('(Glassdoor est.)', '',regex = True)

# %%
uncleaned_data['Salary_Estimate']
# Out:
# 0      $137K-$171K ()
# 1      $137K-$171K ()
# 2      $137K-$171K ()
# 3      $137K-$171K ()
# 4      $137K-$171K ()
#             ...
# 667    $105K-$167K ()
# 668    $105K-$167K ()
# 669    $105K-$167K ()
# 670    $105K-$167K ()
# 671    $105K-$167K ()
# Name: Salary_Estimate, Length: 672, dtype: object

# %%
uncleaned_data['Salary_Estimate'] = uncleaned_data['Salary_Estimate'].str.replace('[K,$,(Employer est.)]', '',regex = True)

# %%
uncleaned_data['Salary_Estimate']
# Out:
# 0      137-171
# 1      137-171
# 2      137-171
# 3      137-171
# 4      137-171
#         ...
# 667    105-167
# 668    105-167
# 669    105-167
# 670    105-167
# 671    105-167
# Name: Salary_Estimate, Length: 672, dtype: object

# %%
 uncleaned_data['Salary_Estimate'].str.split('-', n=2, expand=True)
# Out:
#        0    1
# 0    137  171
# 1    137  171
# 2    137  171
# 3    137  171
# 4    137  171
# ..   ...  ...
# 667  105  167
# 668  105  167
# 669  105  167
# 670  105  167
# 671  105  167
#
# [672 rows x 2 columns]

# %%
 uncleaned_data['min_salary'] = uncleaned_data['Salary_Estimate'].str.split('-').str[0].astype(int)

# %%
 uncleaned_data['min_salary']
# Out:
# 0      137
# 1      137
# 2      137
# 3      137
# 4      137
#       ...
# 667    105
# 668    105
# 669    105
# 670    105
# 671    105
# Name: min_salary, Length: 672, dtype: int32

# %% [markdown]
# ## Split the salary column into 3 parts, minimum, average, maximum salary

# %%
 uncleaned_data['max_salary'] = uncleaned_data['Salary_Estimate'].str.split('-').str[1].astype(int)

# %%
 uncleaned_data['max_salary']
# Out:
# 0      171
# 1      171
# 2      171
# 3      171
# 4      171
#       ...
# 667    167
# 668    167
# 669    167
# 670    167
# 671    167
# Name: max_salary, Length: 672, dtype: int32

# %%
 uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...    -1.0
# 669  Join a thriving company that is changing the w...    -1.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#                   Company_Name           Location            Headquarters  \
# 0             Healthfirst\n3.1       New York, NY            New York, NY
# 1                 ManTech\n4.2      Chantilly, VA             Herndon, VA
# 2          Analysis Group\n3.8         Boston, MA              Boston, MA
# 3                 INFICON\n3.5         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions\n2.9       New York, NY            New York, NY
# ..                         ...                ...                     ...
# 667              TRANZACT\n3.6       Fort Lee, NJ            Fort Lee, NJ
# 668                       JKGT  San Francisco, CA                      -1
# 669                 AccessHope      Irwindale, CA                      -1
# 670  ChaTeck Incorporated\n5.0  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers\n2.7       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                       -1       -1                       -1
# 669                       -1       -1                       -1
# 670        1 to 50 employees       -1        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                     -1                 -1
# 669                                     -1                 -1
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  min_salary  max_salary
# 0      Unknown / Non-Applicable         137         171
# 1        $1 to $2 billion (USD)         137         171
# 2    $100 to $500 million (USD)         137         171
# 3    $100 to $500 million (USD)         137         171
# 4      Unknown / Non-Applicable         137         171
# ..                          ...         ...         ...
# 667    Unknown / Non-Applicable         105         167
# 668                          -1         105         167
# 669                          -1         105         167
# 670      $1 to $5 million (USD)         105         167
# 671      $1 to $2 billion (USD)         105         167
#
# [672 rows x 15 columns]

# %%
 uncleaned_data['average_salary']=uncleaned_data[['min_salary', 'max_salary']].mean(axis=1)

# %%
uncleaned_data['average_salary']
# Out:
# 0      154.0
# 1      154.0
# 2      154.0
# 3      154.0
# 4      154.0
#        ...
# 667    136.0
# 668    136.0
# 669    136.0
# 670    136.0
# 671    136.0
# Name: average_salary, Length: 672, dtype: float64

# %%
uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...    -1.0
# 669  Join a thriving company that is changing the w...    -1.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#                   Company_Name           Location            Headquarters  \
# 0             Healthfirst\n3.1       New York, NY            New York, NY
# 1                 ManTech\n4.2      Chantilly, VA             Herndon, VA
# 2          Analysis Group\n3.8         Boston, MA              Boston, MA
# 3                 INFICON\n3.5         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions\n2.9       New York, NY            New York, NY
# ..                         ...                ...                     ...
# 667              TRANZACT\n3.6       Fort Lee, NJ            Fort Lee, NJ
# 668                       JKGT  San Francisco, CA                      -1
# 669                 AccessHope      Irwindale, CA                      -1
# 670  ChaTeck Incorporated\n5.0  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers\n2.7       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                       -1       -1                       -1
# 669                       -1       -1                       -1
# 670        1 to 50 employees       -1        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                     -1                 -1
# 669                                     -1                 -1
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  min_salary  max_salary  average_salary
# 0      Unknown / Non-Applicable         137         171           154.0
# 1        $1 to $2 billion (USD)         137         171           154.0
# 2    $100 to $500 million (USD)         137         171           154.0
# 3    $100 to $500 million (USD)         137         171           154.0
# 4      Unknown / Non-Applicable         137         171           154.0
# ..                          ...         ...         ...             ...
# 667    Unknown / Non-Applicable         105         167           136.0
# 668                          -1         105         167           136.0
# 669                          -1         105         167           136.0
# 670      $1 to $5 million (USD)         105         167           136.0
# 671      $1 to $2 billion (USD)         105         167           136.0
#
# [672 rows x 16 columns]

# %% [markdown]
# ## In the company_name column, delete everything after the “\n”

# %%
uncleaned_data['Company_Name'] = uncleaned_data['Company_Name'].str.split('\n').str[0]

# %%
 uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...    -1.0
# 669  Join a thriving company that is changing the w...    -1.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA                      -1
# 669            AccessHope      Irwindale, CA                      -1
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                       -1       -1                       -1
# 669                       -1       -1                       -1
# 670        1 to 50 employees       -1        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                     -1                 -1
# 669                                     -1                 -1
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  min_salary  max_salary  average_salary
# 0      Unknown / Non-Applicable         137         171           154.0
# 1        $1 to $2 billion (USD)         137         171           154.0
# 2    $100 to $500 million (USD)         137         171           154.0
# 3    $100 to $500 million (USD)         137         171           154.0
# 4      Unknown / Non-Applicable         137         171           154.0
# ..                          ...         ...         ...             ...
# 667    Unknown / Non-Applicable         105         167           136.0
# 668                          -1         105         167           136.0
# 669                          -1         105         167           136.0
# 670      $1 to $5 million (USD)         105         167           136.0
# 671      $1 to $2 billion (USD)         105         167           136.0
#
# [672 rows x 16 columns]

# %%
uncleaned_data['Company_Name']
# Out:
# 0               Healthfirst
# 1                   ManTech
# 2            Analysis Group
# 3                   INFICON
# 4        Affinity Solutions
#                ...
# 667                TRANZACT
# 668                    JKGT
# 669              AccessHope
# 670    ChaTeck Incorporated
# 671           1-800-Flowers
# Name: Company_Name, Length: 672, dtype: object

# %% [markdown]
# ## Review the location column and look for inconsistencies: You might need to split the column into 3 parts (State, location, City)

# %%
uncleaned_data['Location'].str.split(',')
# Out:
# 0           [New York,  NY]
# 1          [Chantilly,  VA]
# 2             [Boston,  MA]
# 3             [Newton,  MA]
# 4           [New York,  NY]
#                ...
# 667         [Fort Lee,  NJ]
# 668    [San Francisco,  CA]
# 669        [Irwindale,  CA]
# 670    [San Francisco,  CA]
# 671         [New York,  NY]
# Name: Location, Length: 672, dtype: object

# %%
import numpy as np 
uncleaned_data.replace(-1, 0, inplace=True)

# %%
import numpy as np
import datetime

# %%
uncleaned_data[['job_state','same_state','company_age']] = uncleaned_data['Location'].str.split(', ', expand=True)
uncleaned_data['same_state'] = np.where(uncleaned_data['Location'] ==uncleaned_data['Headquarters'], 1, 0)
uncleaned_data['company_age'] = np.where(uncleaned_data['Founded'] == -1, np.nan, 
                                       datetime.datetime.now().year - uncleaned_data['Founded']).astype(int)

# %%
uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA                      -1
# 669            AccessHope      Irwindale, CA                      -1
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                       -1        0                       -1
# 669                       -1        0                       -1
# 670        1 to 50 employees        0        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                     -1                 -1
# 669                                     -1                 -1
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  min_salary  max_salary  average_salary  \
# 0      Unknown / Non-Applicable         137         171           154.0
# 1        $1 to $2 billion (USD)         137         171           154.0
# 2    $100 to $500 million (USD)         137         171           154.0
# 3    $100 to $500 million (USD)         137         171           154.0
# 4      Unknown / Non-Applicable         137         171           154.0
# ..                          ...         ...         ...             ...
# 667    Unknown / Non-Applicable         105         167           136.0
# 668                          -1         105         167           136.0
# 669                          -1         105         167           136.0
# 670      $1 to $5 million (USD)         105         167           136.0
# 671      $1 to $2 billion (USD)         105         167           136.0
#
#          job_state  same_state  company_age
# 0         New York           1           30
# 1        Chantilly           0           55
# 2           Boston           1           42
# 3           Newton           0           23
# 4         New York           1           25
# ..             ...         ...          ...
# 667       Fort Lee           1           34
# 668  San Francisco           0         2023
# 669      Irwindale           0         2023
# 670  San Francisco           0         2023
# 671       New York           0           47
#
# [672 rows x 19 columns]

# %% [markdown]
# ## In the industry column, replace -1 with n/a . Note this is only for the industry column. For other columns -1 will mean something else and hence can be dropped or filled in with other values

# %%
uncleaned_data['Industry'] = uncleaned_data['Industry'].replace('-1', 'n/a')

# %%
uncleaned_data['Industry']
# Out:
# 0                         Insurance Carriers
# 1                     Research & Development
# 2                                 Consulting
# 3      Electrical & Electronic Manufacturing
# 4                    Advertising & Marketing
#                        ...
# 667                  Advertising & Marketing
# 668                                      n/a
# 669                                      n/a
# 670                  Advertising & Marketing
# 671                                Wholesale
# Name: Industry, Length: 672, dtype: object

# %%
 uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA                      -1
# 669            AccessHope      Irwindale, CA                      -1
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                       -1        0                       -1
# 669                       -1        0                       -1
# 670        1 to 50 employees        0        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                    n/a                 -1
# 669                                    n/a                 -1
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  min_salary  max_salary  average_salary  \
# 0      Unknown / Non-Applicable         137         171           154.0
# 1        $1 to $2 billion (USD)         137         171           154.0
# 2    $100 to $500 million (USD)         137         171           154.0
# 3    $100 to $500 million (USD)         137         171           154.0
# 4      Unknown / Non-Applicable         137         171           154.0
# ..                          ...         ...         ...             ...
# 667    Unknown / Non-Applicable         105         167           136.0
# 668                          -1         105         167           136.0
# 669                          -1         105         167           136.0
# 670      $1 to $5 million (USD)         105         167           136.0
# 671      $1 to $2 billion (USD)         105         167           136.0
#
#          job_state  same_state  company_age
# 0         New York           1           30
# 1        Chantilly           0           55
# 2           Boston           1           42
# 3           Newton           0           23
# 4         New York           1           25
# ..             ...         ...          ...
# 667       Fort Lee           1           34
# 668  San Francisco           0         2023
# 669      Irwindale           0         2023
# 670  San Francisco           0         2023
# 671       New York           0           47
#
# [672 rows x 19 columns]

# %%
uncleaned_data.replace('-1', 'Not known', inplace=True)

# %%
uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA               Not known
# 669            AccessHope      Irwindale, CA               Not known
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                Not known        0                Not known
# 669                Not known        0                Not known
# 670        1 to 50 employees        0        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                    n/a          Not known
# 669                                    n/a          Not known
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  min_salary  max_salary  average_salary  \
# 0      Unknown / Non-Applicable         137         171           154.0
# 1        $1 to $2 billion (USD)         137         171           154.0
# 2    $100 to $500 million (USD)         137         171           154.0
# 3    $100 to $500 million (USD)         137         171           154.0
# 4      Unknown / Non-Applicable         137         171           154.0
# ..                          ...         ...         ...             ...
# 667    Unknown / Non-Applicable         105         167           136.0
# 668                   Not known         105         167           136.0
# 669                   Not known         105         167           136.0
# 670      $1 to $5 million (USD)         105         167           136.0
# 671      $1 to $2 billion (USD)         105         167           136.0
#
#          job_state  same_state  company_age
# 0         New York           1           30
# 1        Chantilly           0           55
# 2           Boston           1           42
# 3           Newton           0           23
# 4         New York           1           25
# ..             ...         ...          ...
# 667       Fort Lee           1           34
# 668  San Francisco           0         2023
# 669      Irwindale           0         2023
# 670  San Francisco           0         2023
# 671       New York           0           47
#
# [672 rows x 19 columns]

# %% [markdown]
# ## From the job description column, extract the most popular skillfound in the corresponding job description and 0 if the skill is not found in the corresponding job description.

# %%
skills = ['Python', 'excel', 'handoop', 'spark', 'aws', 'tableau','Big Data']
for skill in skills:
    uncleaned_data[skill.lower()] = uncleaned_data['Job Description'].str.contains(skill, case=False, regex=True).astype(int)

# %%
 uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA               Not known
# 669            AccessHope      Irwindale, CA               Not known
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  ...  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization  ...
# 1    5001 to 10000 employees     1968         Company - Public  ...
# 2     1001 to 5000 employees     1981  Private Practice / Firm  ...
# 3      501 to 1000 employees     2000         Company - Public  ...
# 4        51 to 200 employees     1998        Company - Private  ...
# ..                       ...      ...                      ...  ...
# 667   1001 to 5000 employees     1989        Company - Private  ...
# 668                Not known        0                Not known  ...
# 669                Not known        0                Not known  ...
# 670        1 to 50 employees        0        Company - Private  ...
# 671   1001 to 5000 employees     1976         Company - Public  ...
#
#          job_state same_state company_age  python  excel  handoop spark  aws  \
# 0         New York          1          30       0      0        0     0    1
# 1        Chantilly          0          55       0      0        0     0    0
# 2           Boston          1          42       1      1        0     0    1
# 3           Newton          0          23       1      1        0     0    1
# 4         New York          1          25       1      1        0     0    0
# ..             ...        ...         ...     ...    ...      ...   ...  ...
# 667       Fort Lee          1          34       1      1        0     0    0
# 668  San Francisco          0        2023       0      0        0     0    0
# 669      Irwindale          0        2023       1      1        0     0    0
# 670  San Francisco          0        2023       1      0        0     1    0
# 671       New York          0          47       1      1        0     0    0
#
#      tableau  big data
# 0          0         0
# 1          0         1
# 2          0         0
# 3          0         0
# 4          0         0
# ..       ...       ...
# 667        1         1
# 668        0         0
# 669        1         0
# 670        0         1
# 671        1         0
#
# [672 rows x 26 columns]

# %% [markdown]
# ## Additional Data Cleaning

# %%
uncleaned_data['job_simp'] = uncleaned_data['Job Title'].apply(lambda x: 'Data Scientist' if 'data scientist' in str(x).lower() else pd.NA)

# %%
uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA               Not known
# 669            AccessHope      Irwindale, CA               Not known
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  ...  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization  ...
# 1    5001 to 10000 employees     1968         Company - Public  ...
# 2     1001 to 5000 employees     1981  Private Practice / Firm  ...
# 3      501 to 1000 employees     2000         Company - Public  ...
# 4        51 to 200 employees     1998        Company - Private  ...
# ..                       ...      ...                      ...  ...
# 667   1001 to 5000 employees     1989        Company - Private  ...
# 668                Not known        0                Not known  ...
# 669                Not known        0                Not known  ...
# 670        1 to 50 employees        0        Company - Private  ...
# 671   1001 to 5000 employees     1976         Company - Public  ...
#
#     same_state company_age python  excel  handoop  spark aws  tableau  \
# 0            1          30      0      0        0      0   1        0
# 1            0          55      0      0        0      0   0        0
# 2            1          42      1      1        0      0   1        0
# 3            0          23      1      1        0      0   1        0
# 4            1          25      1      1        0      0   0        0
# ..         ...         ...    ...    ...      ...    ...  ..      ...
# 667          1          34      1      1        0      0   0        1
# 668          0        2023      0      0        0      0   0        0
# 669          0        2023      1      1        0      0   0        1
# 670          0        2023      1      0        0      1   0        0
# 671          0          47      1      1        0      0   0        1
#
#      big data        job_simp
# 0           0  Data Scientist
# 1           1  Data Scientist
# 2           0  Data Scientist
# 3           0  Data Scientist
# 4           0  Data Scientist
# ..        ...             ...
# 667         1  Data Scientist
# 668         0  Data Scientist
# 669         0  Data Scientist
# 670         1  Data Scientist
# 671         0  Data Scientist
#
# [672 rows x 27 columns]

# %%
def seniority(title):
    if 'Senior' in title:
        return 'senior'
    elif 'Sr' in title:
        return 'senior'
    elif 'Jr' in title: 
        return 'junior'
        
    else:
        return'NA'
    
    uncleaned_data['Seniority']

uncleaned_data['seniority'] = uncleaned_data['Job Title'].apply(seniority)

# %%
uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA               Not known
# 669            AccessHope      Irwindale, CA               Not known
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  ...  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization  ...
# 1    5001 to 10000 employees     1968         Company - Public  ...
# 2     1001 to 5000 employees     1981  Private Practice / Firm  ...
# 3      501 to 1000 employees     2000         Company - Public  ...
# 4        51 to 200 employees     1998        Company - Private  ...
# ..                       ...      ...                      ...  ...
# 667   1001 to 5000 employees     1989        Company - Private  ...
# 668                Not known        0                Not known  ...
# 669                Not known        0                Not known  ...
# 670        1 to 50 employees        0        Company - Private  ...
# 671   1001 to 5000 employees     1976         Company - Public  ...
#
#     company_age python excel  handoop  spark  aws tableau  big data  \
# 0            30      0     0        0      0    1       0         0
# 1            55      0     0        0      0    0       0         1
# 2            42      1     1        0      0    1       0         0
# 3            23      1     1        0      0    1       0         0
# 4            25      1     1        0      0    0       0         0
# ..          ...    ...   ...      ...    ...  ...     ...       ...
# 667          34      1     1        0      0    0       1         1
# 668        2023      0     0        0      0    0       0         0
# 669        2023      1     1        0      0    0       1         0
# 670        2023      1     0        0      1    0       0         1
# 671          47      1     1        0      0    0       1         0
#
#            job_simp  seniority
# 0    Data Scientist     senior
# 1    Data Scientist         NA
# 2    Data Scientist         NA
# 3    Data Scientist         NA
# 4    Data Scientist         NA
# ..              ...        ...
# 667  Data Scientist         NA
# 668  Data Scientist         NA
# 669  Data Scientist         NA
# 670  Data Scientist         NA
# 671  Data Scientist         NA
#
# [672 rows x 28 columns]

# %%
columns_to_drop = ['Founded',] 
uncleaned_data = uncleaned_data.drop(columns=columns_to_drop, errors='ignore')

# %%
uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA               Not known
# 669            AccessHope      Irwindale, CA               Not known
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size        Type of ownership  \
# 0     1001 to 5000 employees   Nonprofit Organization
# 1    5001 to 10000 employees         Company - Public
# 2     1001 to 5000 employees  Private Practice / Firm
# 3      501 to 1000 employees         Company - Public
# 4        51 to 200 employees        Company - Private
# ..                       ...                      ...
# 667   1001 to 5000 employees        Company - Private
# 668                Not known                Not known
# 669                Not known                Not known
# 670        1 to 50 employees        Company - Private
# 671   1001 to 5000 employees         Company - Public
#
#                                   Industry  ... company_age python  excel  \
# 0                       Insurance Carriers  ...          30      0      0
# 1                   Research & Development  ...          55      0      0
# 2                               Consulting  ...          42      1      1
# 3    Electrical & Electronic Manufacturing  ...          23      1      1
# 4                  Advertising & Marketing  ...          25      1      1
# ..                                     ...  ...         ...    ...    ...
# 667                Advertising & Marketing  ...          34      1      1
# 668                                    n/a  ...        2023      0      0
# 669                                    n/a  ...        2023      1      1
# 670                Advertising & Marketing  ...        2023      1      0
# 671                              Wholesale  ...          47      1      1
#
#      handoop  spark aws  tableau  big data        job_simp  seniority
# 0          0      0   1        0         0  Data Scientist     senior
# 1          0      0   0        0         1  Data Scientist         NA
# 2          0      0   1        0         0  Data Scientist         NA
# 3          0      0   1        0         0  Data Scientist         NA
# 4          0      0   0        0         0  Data Scientist         NA
# ..       ...    ...  ..      ...       ...             ...        ...
# 667        0      0   0        1         1  Data Scientist         NA
# 668        0      0   0        0         0  Data Scientist         NA
# 669        0      0   0        1         0  Data Scientist         NA
# 670        0      1   0        0         1  Data Scientist         NA
# 671        0      0   0        1         0  Data Scientist         NA
#
# [672 rows x 27 columns]

# %%
uncleaned_data = uncleaned_data.loc[~uncleaned_data['Location'].isin(['California','Texas', 'Utah', 'Remote', 'New Jersey'])]

# %%
uncleaned_data
# Out:
#              Job Title Salary_Estimate  \
# 0    Sr Data Scientist         137-171
# 1       Data Scientist         137-171
# 2       Data Scientist         137-171
# 3       Data Scientist         137-171
# 4       Data Scientist         137-171
# ..                 ...             ...
# 667     Data Scientist         105-167
# 668     Data Scientist         105-167
# 669     Data Scientist         105-167
# 670     Data Scientist         105-167
# 671     Data Scientist         105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...     0.0
# 669  Join a thriving company that is changing the w...     0.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company_Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 667              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                  JKGT  San Francisco, CA               Not known
# 669            AccessHope      Irwindale, CA               Not known
# 670  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size        Type of ownership  \
# 0     1001 to 5000 employees   Nonprofit Organization
# 1    5001 to 10000 employees         Company - Public
# 2     1001 to 5000 employees  Private Practice / Firm
# 3      501 to 1000 employees         Company - Public
# 4        51 to 200 employees        Company - Private
# ..                       ...                      ...
# 667   1001 to 5000 employees        Company - Private
# 668                Not known                Not known
# 669                Not known                Not known
# 670        1 to 50 employees        Company - Private
# 671   1001 to 5000 employees         Company - Public
#
#                                   Industry  ... company_age python  excel  \
# 0                       Insurance Carriers  ...          30      0      0
# 1                   Research & Development  ...          55      0      0
# 2                               Consulting  ...          42      1      1
# 3    Electrical & Electronic Manufacturing  ...          23      1      1
# 4                  Advertising & Marketing  ...          25      1      1
# ..                                     ...  ...         ...    ...    ...
# 667                Advertising & Marketing  ...          34      1      1
# 668                                    n/a  ...        2023      0      0
# 669                                    n/a  ...        2023      1      1
# 670                Advertising & Marketing  ...        2023      1      0
# 671                              Wholesale  ...          47      1      1
#
#      handoop  spark aws  tableau  big data        job_simp  seniority
# 0          0      0   1        0         0  Data Scientist     senior
# 1          0      0   0        0         1  Data Scientist         NA
# 2          0      0   1        0         0  Data Scientist         NA
# 3          0      0   1        0         0  Data Scientist         NA
# 4          0      0   0        0         0  Data Scientist         NA
# ..       ...    ...  ..      ...       ...             ...        ...
# 667        0      0   0        1         1  Data Scientist         NA
# 668        0      0   0        0         0  Data Scientist         NA
# 669        0      0   0        1         0  Data Scientist         NA
# 670        0      1   0        0         1  Data Scientist         NA
# 671        0      0   0        1         0  Data Scientist         NA
#
# [660 rows x 27 columns]

# %% [markdown]
# ## Export/save file to a .csv using pandas

# %%
uncleaned_data.to_csv('Question2.csv', index=False)
